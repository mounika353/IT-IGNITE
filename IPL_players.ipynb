# %% [markdown]
# <a href="https://colab.research.google.com/github/mounika353/IT-IGNITE/blob/main/IPL_players.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
psd = pd.read_excel('ipl player.csv.xlsx')
print(psd.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40 entries, 0 to 39
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Player       40 non-null     object
#  1   Team         40 non-null     object
#  2   Matches      40 non-null     int64
#  3   Runs         40 non-null     int64
#  4   Strike Rate  40 non-null     float64
#  5   Wickets      40 non-null     int64
#  6   Economy      40 non-null     float64
#  7   Sixes        40 non-null     int64
#  8   Average      40 non-null     float64
# dtypes: float64(3), int64(4), object(2)
# memory usage: 2.9+ KB
# None

# %%
psd.head()
# Out:
#           Player Team  Matches  Runs  Strike Rate  Wickets  Economy  Sixes  \
# 0    Virat Kohli  RCB       14   741        154.7        0      0.0     38
# 1   Rohit Sharma   MI       14   520        145.2        0      0.0     29
# 2       MS Dhoni  CSK       14   320        152.3        0      0.0     18
# 3       KL Rahul  LSG       14   610        141.8        0      0.0     24
# 4  Hardik Pandya   MI       14   410        157.6       11      8.1     22
#
#    Average
# 0     61.7
# 1     40.0
# 2     32.0
# 3     50.8
# 4     34.1

# %%
psd.shape
# Out:
# (40, 9)

# %%
list(psd.columns)
# Out:
# ['Player',
#  'Team',
#  'Matches',
#  'Runs',
#  'Strike Rate',
#  'Wickets',
#  'Economy',
#  'Sixes',
#  'Average']

# %%
psd.isnull().sum()
# Out:
# Player         0
# Team           0
# Matches        0
# Runs           0
# Strike Rate    0
# Wickets        0
# Economy        0
# Sixes          0
# Average        0
# dtype: int64

# %%
psd['Team'].value_counts().plot.pie(figsize=(5,8),autopct='%1.1f%%')
# Out:
# <Axes: ylabel='count'>
